# %% [markdown]
# ## Video Preview Creator (adapted for VIS 2021)
#
# Creates a custom title slide for each author submitted video and puts it in front of the submitted video (approx. 5 sec title + 25 sec video)

# %% [markdown]
# ### Requirements
#
# system installs:
#
#
# cairo : check https://cairocffi.readthedocs.io/en/stable/overview.html#installing-cairocffi
#
# ffmpeg: should be installed somewhere in the system path (such that running `ffmpeg` from the command line works.)
#
# *make sure they are in the system path
#
#
# And all the following python packages

# %%
import pandas as pd

import os
import sys
import click
import cairocffi as cairo
import subprocess

import subprocess
import yaml
import wave
import os
import re

# %% [markdown]
# #### Redapted from the previous year script

# %%
def probe( filename ):
    '''get some information about a video file'''

    proc = subprocess.Popen( [
            'ffprobe', 
            '-show_format',
            '-show_streams',
            '-print_format', 'json',
            '-i', filename
        ],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE )

    out, err = proc.communicate()

    if proc.returncode:
        return None

    raw_info = yaml.load(out)

    info          = dict()                
    info['video'] = dict()
    info['audio'] = dict()

    info['duration'] = float( raw_info['format']['duration'] )
    info['size']     = float( raw_info['format']['size'] ) / 1048576.

    for s in raw_info['streams']:

        if s['codec_type'] == 'video':
            #print(s)
            info['video']['codec']  = s['codec_name']
            info['video']['format'] = s['pix_fmt']
            info['video']['width']  = int( s['width'] )
            info['video']['height'] = int( s['height'] )
            #info['video']['aspect'] = s['display_aspect_ratio']
            info['video']['fps']    = s['r_frame_rate']
            
        elif s['codec_type'] == 'audio':
            
            info['audio']['codec'] = s['codec_name']

    if 'codec' not in info['audio']:
        info['audio']['codec'] = '-'

    return info

# %%
def generate_vp(title_data):
   
    final = cairo.ImageSurface(cairo.FORMAT_ARGB32, 1920, 1080)
    ctx = cairo.Context(final)

    def linebreak(text, max_width, sep=' '):
        lines = []

        for text in text.split("\\n"):
            tokens = text.split(sep)
            line = []

            for token in tokens:
                extline = line + [token]
                width = ctx.text_extents(sep.join(extline))[2]

                if width > max_width:
                    lines.append((sep.join(line) + sep))
                    line = [token]
                else:
                    line = extline

            lines.append(sep.join(line))

        return [l.strip() for l in lines]

    def draw_text(text, x, y, size):

        ctx.set_font_size(size)

        y += ctx.font_extents()[0]

        for num, line in enumerate(text):
            ctx.move_to(x, y)
            ctx.show_text(line)
            y = y + 1.2 * size

    img_bkgnd = cairo.ImageSurface.create_from_png( 'preview-background 2021_yellow.png' )

    # clear image
    ctx.rectangle( 0, 0, 1920, 1080 )
    ctx.set_source_rgba( 1, 1, 1, 1 )
    ctx.fill()

    ctx.set_source_surface( img_bkgnd )
    ctx.paint()

    # draw paper type
    ctx.select_font_face( "Futura Medium" )
    ctx.set_font_size( 30 )
    ctx.set_source_rgba( 1, 1, 1, 1 )

    draw_text( [title_data[0].upper()], 1080, 112, 50 )

    # draw title
    ctx.select_font_face( "Gotham Bold" )
    ctx.set_source_rgba( 1, 1, 1, 1 )

    for fontsize in range( 60, 50, -2 ):

        ctx.set_font_size( fontsize )
        lines = linebreak( title_data[1], 1800 )

        if len(lines) < 4:
            break

    if len(lines) > 2:
        ctx.translate( 0,  0.3*fontsize )
    if len(lines) < 1:
        ctx.translate( 0,  0.3*fontsize )

    draw_text( lines, 90, 420-1.2*fontsize*len(lines), fontsize )

    # draw authors
    ctx.select_font_face( "Gotham Book" )
    ctx.set_source_rgba( 1, 1, 1, 1 )

    for author_fontsize in range( 50, 40, -2 ):

        ctx.set_font_size( author_fontsize )
        lines = linebreak( title_data[2], 1800, ',' )

        if len(lines) < 4:
            break

    draw_text( lines, 90, 480, 35 )
    
    # draw awards information
    if(title_data[6] == 'Best Paper' or title_data[6] == 'Honarable Mentions'):
        ctx.select_font_face( "Gotham Bold" )
        ctx.set_source_rgba( 1, 1, 1, 1 )

        for session_fontsize in range( 60, 50, -2 ):

            ctx.set_font_size( session_fontsize )
            lines = linebreak( '*'+title_data[6], 1800, ',' )

            if len(lines) < 4:
                break

        draw_text( lines, 90, 540, 40 )
    
    # draw session info
    ctx.select_font_face( "Gotham Bold" )
    ctx.set_source_rgba( 1, 1, 1, 1 )

    for session_fontsize in range( 80, 40, -2 ):

        ctx.set_font_size( session_fontsize )
        lines = linebreak( title_data[4], 1800, ',' )

        if len(lines) < 4:
            break

    draw_text( lines, 90, 700, 40 )

    png_file = 'tmp_yellow.png'

    final.write_to_png( png_file )
    
    # use FFMPEG to prepend image to video
    # filter syntax: https://ffmpeg.org/ffmpeg-filters.html#Filtergraph-syntax-1
    
    # check if preview already exists
    outfile = os.path.join( title_data[5] )

#     if os.path.exists( outfile ):
#         print( '  preview found in', outfile )
#         return outfile

    #input_file = find_video_file( meta['id'] )
    input_file = title_data[3]
    info = probe( input_file )
    
    filter  = '[0:v]trim=duration=5,fade=t=out:st=4.5:d=0.5[v0];'
    filter += 'aevalsrc=0:d=5[a0];'
    filter += '[1:v]scale=w=1920:h=1080[v1];'

    if info['audio']['codec'] == '-':
        filter += 'aevalsrc=0:d=25[a1];'
    else:
        filter += '[1:a]anull[a1];'

    filter += '[v0][a0][v1][a1]concat=n=2:v=1:a=1[v][a]'
    
    cmd = [
        'ffmpeg',
        '-v', 'error',
        '-framerate', info['video']['fps'],
        '-f', 'image2pipe',
        '-vcodec', 'png',
        '-loop', '1',
        '-i', png_file,
        '-i', input_file,
        '-filter_complex', filter,
        '-map', '[v]',
        '-map', '[a]',
        '-c:v', 'libx264',
        '-pix_fmt', 'yuv420p',
        '-profile:v', 'main',
        '-preset', 'slow',
        '-y', outfile
    ]

    try:
        p = subprocess.Popen( cmd )
        p.wait()
    except:
        # on error, delete the output file
        os.unlink( outfile )
        print( '  abort, deleted', outfile )
        raise

# %%
df = pd.read_excel(open('VP_2021_videodata.xlsx', 'rb'),sheet_name='VP_ShortPaper', engine='openpyxl')

# %%
df
# Out:
#     Submission ID             Type  \
# 0            1012  Vis Short Paper
# 1            1013  Vis Short Paper
# 2            1016  Vis Short Paper
# 3            1024  Vis Short Paper
# 4            1025  Vis Short Paper
# 5            1030  Vis Short Paper
# 6            1032  Vis Short Paper
# 7            1033  Vis Short Paper
# 8            1034  Vis Short Paper
# 9            1035  Vis Short Paper
# 10           1047  Vis Short Paper
# 11           1048  Vis Short Paper
# 12           1050  Vis Short Paper
# 13           1054  Vis Short Paper
# 14           1064  Vis Short Paper
# 15           1065  Vis Short Paper
# 16           1072  Vis Short Paper
# 17           1073  Vis Short Paper
# 18           1082  Vis Short Paper
# 19           1087  Vis Short Paper
# 20           1092  Vis Short Paper
# 21           1105  Vis Short Paper
# 22           1111  Vis Short Paper
# 23           1113  Vis Short Paper
# 24           1122  Vis Short Paper
# 25           1128  Vis Short Paper
# 26           1129  Vis Short Paper
# 27           1136  Vis Short Paper
# 28           1139  Vis Short Paper
# 29           1146  Vis Short Paper
# 30           1151  Vis Short Paper
# 31           1157  Vis Short Paper
# 32           1160  Vis Short Paper
# 33           1161  Vis Short Paper
# 34           1168  Vis Short Paper
# 35           1169  Vis Short Paper
# 36           1170  Vis Short Paper
# 37           1171  Vis Short Paper
# 38           1178  Vis Short Paper
# 39           1184  Vis Short Paper
# 40           1205  Vis Short Paper
#
#                                                 Title  \
# 0   Towards a Survey on Static and Dynamic Hypergr...
# 1   CloudFindr: A Deep Learning Cloud Artifact Mas...
# 2   An Exploration And Validation of Visual Factor...
# 3   Fast & Accurate Gaussian Kernel Density Estima...
# 4   TimeElide: Visual Analysis of Non-Contiguous T...
# 5                    Time-Varying Fuzzy Contour Trees
# 6   A Visual Analytics System for Water Distributi...
# 7   Gemini²: Generating Keyframe-Oriented Animated...
# 8   On The Potential of Zines as a Medium for Visu...
# 9   CellProfiler Analyst Web (CPAW) - Exploration,...
# 10  GeoSneakPique: Visual autocompletion for geosp...
# 11  Semantic Resizing of Charts Through Generaliza...
# 12  Contrastive Identification of Covariate Shift ...
# 13  A Mixed-Initiative Visual Analytics Approach f...
# 14  Atlas: Grammar-based Procedural Generation of ...
# 15  "Why did my AI agent lose?": Visual Analytics ...
# 16  Inspecting the Process of Bank Credit Rating v...
# 17  Narrative Sensemaking: Strategies for Narrativ...
# 18  Bayesian Modelling of Alluvial Diagram Complexity
# 19  Visually Connecting Historical Figures Through...
# 20  Text Visualization and Close Reading for Journ...
# 21  Where and Why is My Bot Failing? A Visual Anal...
# 22  VAINE: Visualization and AI for Natural Experi...
# 23  Ray-traced Shell Traversal of Tetrahedral Mesh...
# 24  Segmentation driven Peeling for Visual Analysi...
# 25                  Exact Analytical Parallel Vectors
# 26  Uncertainty Visualization of the Marching Squa...
# 27  Conceptualizing Visual Analytic Interventions ...
# 28  AiR: An Augmented Reality Application for Visu...
# 29  Intercept Graph: An Interactive Radial Visuali...
# 30  When Red Means Good, Bad, or Canada:Exploring ...
# 31                   How Learners Sketch Data Stories
# 32  Understanding the Effects of Visualizing Missi...
# 33  Semantic Explanation of Interactive Dimensiona...
# 34  Automatic Y-axis Rescaling in Dynamic Visualiz...
# 35  ConVIScope: Visual Analytics for Exploring Pat...
# 36  Does the Layout Really Matter? A Study on Visu...
# 37  Histogram binning revisited with a focus on hu...
# 38  AdViCE: Aggregated Visual Counterfactual Expla...
# 39  Jurassic Mark: Inattentional Blindness for a D...
# 40  Fixation and Creativity in Data Visualization ...
#
#                                               Authors  \
# 0   Maximilian T. Fischer, Alexander Frings, Danie...
# 1   Kalina Borkiewicz, Viraj Shah, J.P. Naiman, Ch...
# 2                  Jun Yuan, Oded Nov, Enrico Bertini
# 3                                        Jeffrey Heer
# 4         Michael Oppermann, Luce Liu, Tamara Munzner
# 5   Anna-Pia Lohfink, Frederike Gartzky, Florian W...
# 6   Yiran Li, Erin Musabandesu, Takanori Fujiwara,...
# 7                         Younghoon Kim, Jeffrey Heer
# 8                                     Andrew M McNutt
# 9   Bella baidak, Yahiya Hussain, Emma Kelminson, ...
# 10  Vidya Setlur, Sarah Battersby, Tracy Kam Hung ...
# 11                        Vidya Setlur, Haeyong Chung
# 12  Matthew Olson, Thuy-Vy Nguyen, Gaurav Dixit, N...
# 13  Fahd Husain, Pascale Proulx, Meng-Wei Chang, R...
# 14  Zhicheng Liu, Chen Chen, Francisco Morales, Yi...
# 15  Delyar Tabatabai, Anita Ruangrotsakun, Jed Irv...
# 16  Qiangqiang Liu, Tangzhi Ye, Zhihua Zhu, Xiaoju...
# 17  Brian Felipe Keith Norambuena, Tanushree Mitra...
# 18  Anjana Arunkumar, Shashank Ginjpalli, Chris Bryan
# 19  Shahid Latif, Shivam Agarwal, Simon Gottschalk...
# 20  Nicole Sultanum, Anastasia Bezerianos, Fanny C...
# 21                           Avi Yaeli, Sergey Zeltyn
# 22  Grace Guo, Maria Glenski, Zhuanyi Huang, Emily...
# 23  Alper Şahıstan, Serkan Demirci, Nate Morrical,...
# 24  Mohit Sharma, Talha Bin Masood, Signe Sidwall ...
# 25                             Hanqi Guo, Tom Peterka
# 26  Tushar M. Athawale, Sudhanshu Sane, Chris R. J...
# 27  Sahaj Vaidya, Jie Cai, Soumyadeep Basu, Azadeh...
# 28  Noble Saji Mathews, Sridhar Chimalakonda, Sure...
# 29                Shaolun Ruan, Yong Wang, Qiang Guan
# 30    Jarryullah Ahmad, Elaine Huynh, Fanny Chevalier
# 31  Rahul Bhargava, Dee Williams, Catherine D'Ignazio
# 32    Hayeong Song, Yu Fu, Bahador Saket, John Stasko
# 33             Yail Bian, Chris North, , Sarah Joseph
# 34                          Jacob Fisher, Remco Chang
# 35  Raymond Li, Enamul Hoque, , Richard Lester, Ra...
# 36  Nicolas Grossmann, Jürgen Bernard, , Manuela W...
# 37                    Raphael Sahann, Torsten Moeller
# 38      Steffen Holter, Oscar Gomez, , Enrico Bertini
# 39                             Tal Boger, Steven Most
# 40               Paul Parsons, Prakash Chandra Shukla
#
#                         Contact Email  \
# 0         max.fischer@uni-konstanz.de
# 1                 kalina@illinois.edu
# 2                     junyuan@nyu.edu
# 3                        jheer@uw.edu
# 4                  opperman@cs.ubc.ca
# 5                lohfink@cs.uni-kl.de
# 6                   ranli@ucdavis.edu
# 7           yhkim01@cs.washington.edu
# 8                 mcnutt@uchicago.edu
# 9             bella.baidak001@umb.edu
# 10                vsetlur@tableau.com
# 11                vsetlur@tableau.com
# 12       minsuk.kahng@oregonstate.edu
# 13                 rosscopy@gmail.com
# 14                   leozcliu@umd.edu
# 15       minsuk.kahng@oregonstate.edu
# 16               qliba@connect.ust.hk
# 17                 briankeithn@vt.edu
# 18                   aarunku5@asu.edu
# 19            shahid.latif@uni-due.de
# 20          nicole.sultanum@gmail.com
# 21                 sergeyz@il.ibm.com
# 22                  gguo31@gatech.edu
# 23      alper.sahistan@bilkent.edu.tr
# 24             mohitsharma@iisc.ac.in
# 25                       hguo@anl.gov
# 26          tushar.athawale@gmail.com
# 27          dasgupta.aritra@gmail.com
# 28               ch19b023@iittp.ac.in
# 29            haywardryan@foxmail.com
# 30           j.ahmad@mail.utoronto.ca
# 31        r.bhargava@northeastern.edu
# 32                hsong300@gatech.edu
# 33                        yali@vt.edu
# 34                jf3148@columbia.edu
# 35                 raymondl@cs.ubc.ca
# 36  nicolas.grossmann@cg.tuwien.ac.at
# 37           johanna.schmidt@vrvis.at
# 38                     sh3628@nyu.edu
# 39                 tal.boger@yale.edu
# 40                parsonsp@purdue.edu
#
#                                              Abstract              Award  \
# 0   Leveraging hypergraph structures to model adva...                NaN
# 1   Artifact removal is an integral component of c...                NaN
# 2   Rule sets are often used in Machine Learning (...                NaN
# 3   Kernel density estimation (KDE) models a discr...                NaN
# 4   We introduce the design and implementation of ...                NaN
# 5   We present a holistic, topology-based visualiz...                NaN
# 6   The optimization of water distribution systems...                NaN
# 7   Complex animated transitions may be easier to ...                NaN
# 8   Zines are a form of small-circulation self-pro...                NaN
# 9   CellProfiler Analyst has enabled the scientifi...                NaN
# 10  How many crimes occurred in the city center? A...                NaN
# 11  Inspired by cartographic generalization princi...  Honorable Mention
# 12  Identifying covariate shift is crucial to maki...                NaN
# 13  Modeling complex systems is a time-consuming, ...                NaN
# 14  We present Atlas, a procedural grammar for con...                NaN
# 15  How can we help domain-knowledgeable users who...                NaN
# 16  Bank credit rating refers to classify commerci...                NaN
# 17  Narrative sensemaking is a fundamental process...                NaN
# 18  Alluvial diagrams are a popular technique for ...                NaN
# 19  To research lives of historical figures and th...                NaN
# 20  Journalistic inquiry often requires analysis a...                NaN
# 21  The ongoing coronavirus pandemic has accelerat...                NaN
# 22  Natural experiments are observational studies ...                NaN
# 23  A well-known method for rendering unstructured...                NaN
# 24  Electronic transitions in molecules due to abs...                NaN
# 25  This paper demonstrates that parallel vector c...  Honorable Mention
# 26  Marching squares (MS) and marching cubes (MC) ...                NaN
# 27  Our work introduces a visual analytic task abs...                NaN
# 28  In order to effectively combat Air Pollution, ...                NaN
# 29  State change comparison of multiple data items...                NaN
# 30  Color palette selection is an essential aspect...                NaN
# 31  \abstract{Learning data storytelling involves ...                NaN
# 32  When performing data analysis, people often co...                NaN
# 33  Interactive dimensionality reduction helps ana...                NaN
# 34  Animated and interactive data visualizations d...                NaN
# 35  The proliferation of text messaging for mobile...                NaN
# 36  In visual interactive labeling, users iterativ...                NaN
# 37  This paper presents a quantitative user study ...                NaN
# 38  Rapid improvements in the performance of machi...                NaN
# 39  Graphs effectively communicate data because th...         Best Paper
# 40  Data visualization design often requires creat...                NaN
#
#                                   Filename  \
# 0         v-short_1012_Fischer_Preview.mp4
# 1                           cloudfindr.mp4
# 2                                      NaN
# 3                                      NaN
# 4       v-short_1025_Oppermann_Preview.mp4
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8          v-short_1034_McNutt_Preview.mp4
# 9                                      NaN
# 10         v-short_1047_Setlur_Preview.mp4
# 11         v-short_1048_Setlur_Preview.mp4
# 12                                     NaN
# 13                                     NaN
# 14            v-short_1064_Liu_Preview.mp4
# 15      v-short_1065_Tabatabai_Preview.mp4
# 16    v-short_ 1072_Qiangqiang_Preview.mp4
# 17                                     NaN
# 18      v-short_1082_Arunkumar_Preview.mp4
# 19                                     NaN
# 20                                     NaN
# 21          v-short_1105_Yaeli_Preview.mp4
# 22                                     NaN
# 23                                     NaN
# 24         v-short_1122_Sharma_Preview.mp4
# 25                                     NaN
# 26       v-short_1129_Athawale_Preview.mp4
# 27                                     NaN
# 28                                     NaN
# 29  v-short_1146_Ruan_Preview(updated).mp4
# 30                                     NaN
# 31       v-short_1157_Bhargava_Preview.mp4
# 32                                     NaN
# 33                                     NaN
# 34         v-short_1168_Fisher_Preview.mp4
# 35                                     NaN
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39          v-short_1184_Boger_Preview.mp4
# 40                                     NaN
#
#                                          Session Name Session Time
# 0   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 1   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 2   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 3   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 4   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 5   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 6   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 7   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 8   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 9   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 10  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 11  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 12  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 13  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 14  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 15  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 16  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 17  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 18  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 19  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 20  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 21  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 22  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 23  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 24  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 25  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 26  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 27  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 28  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 29  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 30  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 31  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 32  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 33  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 34  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 35  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 36  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 37  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 38  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 39  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 40  Social Sciences, Software Tools, Journalism, a...    0800-0810

# %%
#remove entries with no files. probably authors did not submit
clean_df = df.loc[df['Filename'].notna()]

# %%
clean_df
# Out:
#     Submission ID             Type  \
# 0            1012  Vis Short Paper
# 1            1013  Vis Short Paper
# 4            1025  Vis Short Paper
# 8            1034  Vis Short Paper
# 10           1047  Vis Short Paper
# 11           1048  Vis Short Paper
# 14           1064  Vis Short Paper
# 15           1065  Vis Short Paper
# 16           1072  Vis Short Paper
# 18           1082  Vis Short Paper
# 21           1105  Vis Short Paper
# 24           1122  Vis Short Paper
# 26           1129  Vis Short Paper
# 29           1146  Vis Short Paper
# 31           1157  Vis Short Paper
# 34           1168  Vis Short Paper
# 39           1184  Vis Short Paper
#
#                                                 Title  \
# 0   Towards a Survey on Static and Dynamic Hypergr...
# 1   CloudFindr: A Deep Learning Cloud Artifact Mas...
# 4   TimeElide: Visual Analysis of Non-Contiguous T...
# 8   On The Potential of Zines as a Medium for Visu...
# 10  GeoSneakPique: Visual autocompletion for geosp...
# 11  Semantic Resizing of Charts Through Generaliza...
# 14  Atlas: Grammar-based Procedural Generation of ...
# 15  "Why did my AI agent lose?": Visual Analytics ...
# 16  Inspecting the Process of Bank Credit Rating v...
# 18  Bayesian Modelling of Alluvial Diagram Complexity
# 21  Where and Why is My Bot Failing? A Visual Anal...
# 24  Segmentation driven Peeling for Visual Analysi...
# 26  Uncertainty Visualization of the Marching Squa...
# 29  Intercept Graph: An Interactive Radial Visuali...
# 31                   How Learners Sketch Data Stories
# 34  Automatic Y-axis Rescaling in Dynamic Visualiz...
# 39  Jurassic Mark: Inattentional Blindness for a D...
#
#                                               Authors  \
# 0   Maximilian T. Fischer, Alexander Frings, Danie...
# 1   Kalina Borkiewicz, Viraj Shah, J.P. Naiman, Ch...
# 4         Michael Oppermann, Luce Liu, Tamara Munzner
# 8                                     Andrew M McNutt
# 10  Vidya Setlur, Sarah Battersby, Tracy Kam Hung ...
# 11                        Vidya Setlur, Haeyong Chung
# 14  Zhicheng Liu, Chen Chen, Francisco Morales, Yi...
# 15  Delyar Tabatabai, Anita Ruangrotsakun, Jed Irv...
# 16  Qiangqiang Liu, Tangzhi Ye, Zhihua Zhu, Xiaoju...
# 18  Anjana Arunkumar, Shashank Ginjpalli, Chris Bryan
# 21                           Avi Yaeli, Sergey Zeltyn
# 24  Mohit Sharma, Talha Bin Masood, Signe Sidwall ...
# 26  Tushar M. Athawale, Sudhanshu Sane, Chris R. J...
# 29                Shaolun Ruan, Yong Wang, Qiang Guan
# 31  Rahul Bhargava, Dee Williams, Catherine D'Ignazio
# 34                          Jacob Fisher, Remco Chang
# 39                             Tal Boger, Steven Most
#
#                    Contact Email  \
# 0    max.fischer@uni-konstanz.de
# 1            kalina@illinois.edu
# 4             opperman@cs.ubc.ca
# 8            mcnutt@uchicago.edu
# 10           vsetlur@tableau.com
# 11           vsetlur@tableau.com
# 14              leozcliu@umd.edu
# 15  minsuk.kahng@oregonstate.edu
# 16          qliba@connect.ust.hk
# 18              aarunku5@asu.edu
# 21            sergeyz@il.ibm.com
# 24        mohitsharma@iisc.ac.in
# 26     tushar.athawale@gmail.com
# 29       haywardryan@foxmail.com
# 31   r.bhargava@northeastern.edu
# 34           jf3148@columbia.edu
# 39            tal.boger@yale.edu
#
#                                              Abstract               Award  \
# 0   Leveraging hypergraph structures to model adva...                 NaN
# 1   Artifact removal is an integral component of c...                 NaN
# 4   We introduce the design and implementation of ...                 NaN
# 8   Zines are a form of small-circulation self-pro...                 NaN
# 10  How many crimes occurred in the city center? A...                 NaN
# 11  Inspired by cartographic generalization princi...  Honarable Mentions
# 14  We present Atlas, a procedural grammar for con...                 NaN
# 15  How can we help domain-knowledgeable users who...                 NaN
# 16  Bank credit rating refers to classify commerci...                 NaN
# 18  Alluvial diagrams are a popular technique for ...                 NaN
# 21  The ongoing coronavirus pandemic has accelerat...                 NaN
# 24  Electronic transitions in molecules due to abs...                 NaN
# 26  Marching squares (MS) and marching cubes (MC) ...                 NaN
# 29  State change comparison of multiple data items...                 NaN
# 31  \abstract{Learning data storytelling involves ...                 NaN
# 34  Animated and interactive data visualizations d...                 NaN
# 39  Graphs effectively communicate data because th...          Best Paper
#
#                                   Filename  \
# 0         v-short_1012_Fischer_Preview.mp4
# 1                           cloudfindr.mp4
# 4       v-short_1025_Oppermann_Preview.mp4
# 8          v-short_1034_McNutt_Preview.mp4
# 10         v-short_1047_Setlur_Preview.mp4
# 11         v-short_1048_Setlur_Preview.mp4
# 14            v-short_1064_Liu_Preview.mp4
# 15      v-short_1065_Tabatabai_Preview.mp4
# 16    v-short_ 1072_Qiangqiang_Preview.mp4
# 18      v-short_1082_Arunkumar_Preview.mp4
# 21          v-short_1105_Yaeli_Preview.mp4
# 24         v-short_1122_Sharma_Preview.mp4
# 26       v-short_1129_Athawale_Preview.mp4
# 29  v-short_1146_Ruan_Preview(updated).mp4
# 31       v-short_1157_Bhargava_Preview.mp4
# 34         v-short_1168_Fisher_Preview.mp4
# 39          v-short_1184_Boger_Preview.mp4
#
#                                          Session Name Session Time
# 0   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 1   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 4   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 8   Social Sciences, Software Tools, Journalism, a...    0800-0810
# 10  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 11  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 14  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 15  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 16  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 18  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 21  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 24  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 26  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 29  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 31  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 34  Social Sciences, Software Tools, Journalism, a...    0800-0810
# 39  Social Sciences, Software Tools, Journalism, a...    0800-0810

# %%
print('Available videos:', len(clean_df))
print('Total Submissions:', len(df))
# Out:
# Available videos: 17
# Total Submissions: 41

# %%
input_vid_dir = 'video_dir/VIS Short/'
output_vid_dir = 'video_dir/VP_out_VIS Short/'

# %%
for index, row in clean_df.iterrows():

    video_metadata = [row['Type'],
                      row['Title'],
                      row['Authors'],
                      input_vid_dir + row['Filename'],
                      row['Session Name'] + ': ' + row['Session Time'],
                      #'Social Sciences, Software Tools, Journalism, and Storytelling: Friday, 0815 - 0830',
                      output_vid_dir + row['Filename'],
                      row['Award']
                     ]
    
    print(index, video_metadata, '\n\n')
    generate_vp(video_metadata)
# Out:
# 0 ['Vis Short Paper', 'Towards a Survey on Static and Dynamic Hypergraph Visualizations', 'Maximilian T. Fischer, Alexander Frings, Daniel Keim, Daniel Seebacher', 'video_dir/VIS Short/v-short_1012_Fischer_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1012_Fischer_Preview.mp4', nan]
#
#
# 1 ['Vis Short Paper', 'CloudFindr: A Deep Learning Cloud Artifact Masker for Satellite DEM Data', 'Kalina Borkiewicz, Viraj Shah, J.P. Naiman, Chuanyue Shen, Stuart Levy, Jeffrey Carpenter', 'video_dir/VIS Short/cloudfindr.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/cloudfindr.mp4', nan]
#
#
# 4 ['Vis Short Paper', 'TimeElide: Visual Analysis of Non-Contiguous Time Series Slices', 'Michael Oppermann, Luce Liu, Tamara Munzner', 'video_dir/VIS Short/v-short_1025_Oppermann_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1025_Oppermann_Preview.mp4', nan]
#
#
# 8 ['Vis Short Paper', 'On The Potential of Zines as a Medium for Visualization', 'Andrew M McNutt', 'video_dir/VIS Short/v-short_1034_McNutt_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1034_McNutt_Preview.mp4', nan]
#
#
# 10 ['Vis Short Paper', 'GeoSneakPique: Visual autocompletion for geospatial queries', 'Vidya Setlur, Sarah Battersby, Tracy Kam Hung Wong', 'video_dir/VIS Short/v-short_1047_Setlur_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1047_Setlur_Preview.mp4', nan]
#
#
# 11 ['Vis Short Paper', 'Semantic Resizing of Charts Through Generalization: A Case Study with Line Charts', 'Vidya Setlur, Haeyong Chung', 'video_dir/VIS Short/v-short_1048_Setlur_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1048_Setlur_Preview.mp4', 'Honarable Mentions']
#
#
# 14 ['Vis Short Paper', 'Atlas: Grammar-based Procedural Generation of Data Visualizations', 'Zhicheng Liu, Chen Chen, Francisco Morales, Yishan Zhao', 'video_dir/VIS Short/v-short_1064_Liu_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1064_Liu_Preview.mp4', nan]
#
#
# 15 ['Vis Short Paper', '"Why did my AI agent lose?": Visual Analytics for Scaling Up AAR/AI', 'Delyar Tabatabai, Anita Ruangrotsakun, Jed Irvine, Jonathan Dodge, Zeyad Shureih, Kin-Ho Lam, Margaret Burnett, Alan Paul Fern, Minsuk Kahng', 'video_dir/VIS Short/v-short_1065_Tabatabai_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1065_Tabatabai_Preview.mp4', nan]
#
#
# 16 ['Vis Short Paper', 'Inspecting the Process of Bank Credit Rating via Visual Analytics', 'Qiangqiang Liu, Tangzhi Ye, Zhihua Zhu, Xiaojuan Ma, Quan Li', 'video_dir/VIS Short/v-short_ 1072_Qiangqiang_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_ 1072_Qiangqiang_Preview.mp4', nan]
#
#
# 18 ['Vis Short Paper', 'Bayesian Modelling of Alluvial Diagram Complexity', 'Anjana Arunkumar, Shashank Ginjpalli, Chris Bryan', 'video_dir/VIS Short/v-short_1082_Arunkumar_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1082_Arunkumar_Preview.mp4', nan]
#
#
# 21 ['Vis Short Paper', 'Where and Why is My Bot Failing? A Visual Analytics Approach for Investigating Failures in Chatbot Conversation Flows', 'Avi Yaeli, Sergey Zeltyn', 'video_dir/VIS Short/v-short_1105_Yaeli_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1105_Yaeli_Preview.mp4', nan]
#
#
# 24 ['Vis Short Paper', 'Segmentation driven Peeling for Visual Analysis of Electronic Transitions', 'Mohit Sharma, Talha Bin Masood, Signe Sidwall Thygesen, Mathieu Linares, Ingrid Hotz, Vijay Natarajan', 'video_dir/VIS Short/v-short_1122_Sharma_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1122_Sharma_Preview.mp4', nan]
#
#
# 26 ['Vis Short Paper', 'Uncertainty Visualization of the Marching Squares and Marching Cubes Topology Cases', 'Tushar M. Athawale, Sudhanshu Sane, Chris R. Johnson', 'video_dir/VIS Short/v-short_1129_Athawale_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1129_Athawale_Preview.mp4', nan]
#
#
# 29 ['Vis Short Paper', 'Intercept Graph: An Interactive Radial Visualization for Comparison of State Changes', 'Shaolun Ruan, Yong Wang, Qiang Guan', 'video_dir/VIS Short/v-short_1146_Ruan_Preview(updated).mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1146_Ruan_Preview(updated).mp4', nan]
#
#
# 31 ['Vis Short Paper', 'How Learners Sketch Data Stories', "Rahul Bhargava, Dee Williams, Catherine D'Ignazio", 'video_dir/VIS Short/v-short_1157_Bhargava_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1157_Bhargava_Preview.mp4', nan]
#
#
# 34 ['Vis Short Paper', 'Automatic Y-axis Rescaling in Dynamic Visualizations', 'Jacob Fisher, Remco Chang', 'video_dir/VIS Short/v-short_1168_Fisher_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1168_Fisher_Preview.mp4', nan]
#
#
# 39 ['Vis Short Paper', 'Jurassic Mark: Inattentional Blindness for a Datasaurus Reveals that Visualizations are Explored, not Seen', 'Tal Boger, Steven Most', 'video_dir/VIS Short/v-short_1184_Boger_Preview.mp4', 'Social Sciences, Software Tools, Journalism, and Storytelling: 0800-0810', 'video_dir/VP_out_VIS Short/v-short_1184_Boger_Preview.mp4', 'Best Paper']
